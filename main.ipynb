# %%
#################################
from utils.procesador import *
#################################

# %%
############## CONFIGURACIONES ##############
ruta_a_carpeta = "C:/Users/Atmosfera/Desktop/datos_crudos/20260212"
fecha_inicial = "2026-02-01 00:00:00"
fecha_final = "2026-02-12 21:59:59"
ruta_a_carpeta_de_guardado = 'C:/Users/Atmosfera/Desktop/datos_crudos/'
nombre_de_excel_de_salida = "2026020100_2026021221"
#############################################

# %%
############## NO TOCAR ##############
archivos = buscar_archivos_csv(ruta_a_carpeta)

# %%
dic = crear_diccionario_de_boyas(archivos)

# %%
archivos_de_boya = buscar_archivos_csv_de_una_boya(ruta_a_carpeta, "BOT1-06-T50")

# %%
dic = llenar_datos_de_diccionario_de_boyas(dic, ruta_a_carpeta, fecha_inicial, fecha_final)

# %%
df_salida = crear_dataframe_de_salida(dic,fecha_inicial, fecha_final)

# %%
guardar_excel(df_salida, ruta_a_carpeta_de_guardado, nombre_de_excel_de_salida)
# Out:
# Archivo guardado en: C:/Users/Atmosfera/Desktop/datos_crudos/2026020100_2026021221.xlsx
